# %%
from crawler import *

crawler = RTTCrawler("")
movies = crawler.get_popular_movies(128)
# Out:
# The_Holdovers
# Dream_Scenario
# Quiz_Lady
# Monarch_Legacy_of_Monsters
# The_Killer
# Five_Nights_at_Freddy_s
# Dumb_Money
# When_Evil_Lurks
# Talk_to_Me
# The_Creator
# A_Haunting_in_Venice
# Nyad
# Butcher_s_Crossing
# Quiz_Lady
# Locked_In
# Pain_Hustlers
# No_Hard_Feelings
# Old_Dads
# The_Lady_Bird_Diaries
# Polaris
# The_Burial
# Ghosts_of_the_Void
# Captain_Marvel
# Fingernails
# Mission_Impossible_Dead_Reckoning_Part_One
# Ant_Man_and_The_Wasp_Quantumania
# Barbie
# The_Wonderful_Story_of_Henry_Sugar
# Past_Lives
# Saw_X
# Reptile
# The_Girl_in_the_Backseat
# Sound_of_Freedom
# Blue_Beetle
# Spider_Man_Across_the_Spider_Verse
# The_Exorcist_Believer
# Fair_Play
# Your_Lucky_Day
# Please_Don_t_Destroy_The_Treasure_of_Foggy_Mountain
# Downsizing
# 365_Days
# The_Equalizer_3
# Manodrome
# Pencils_vs_Pixels
# Foe
# Gran_Turismo_Based_on_a_True_Story
# Thor_Love_and_Thunder
# Fifty_Shades_of_Grey
# Guardians_of_the_Galaxy_Vol_3
# BlackBerry
# Rumble_Through_the_Dark
# ...

# %%
crawler.process_folder("Comments_Ratings_Files/", "ratings_comments_pairs.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/qujianning/Desktop/UT课程/2023 Fall/ECE1786 NLP/Group Project/FilmEMO/crawler.ipynb 单元格 2 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/qujianning/Desktop/UT%E8%AF%BE%E7%A8%8B/2023%20Fall/ECE1786%20NLP/Group%20Project/FilmEMO/crawler.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> crawler.process_folder("Comments_Ratings_Files/", "ratings_comments_pairs.csv")
#
# AttributeError: 'RTTCrawler' object has no attribute 'process_folder'

# %%
for movie_name in movies[26:]:
    crawler = RTTCrawler(movie_name)
    audience = crawler.extract_audience_comments_and_ratings("All audience")
    if audience:
        crawler.write_comments_to_file(audience, "All audience")
    sleep(1)
# Out:
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /Users/qujianning/Desktop/UT课程/2023 Fall/ECE1786 NLP/Group Project/FilmEMO/crawler.ipynb 单元格 3 line <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/qujianning/Desktop/UT%E8%AF%BE%E7%A8%8B/2023%20Fall/ECE1786%20NLP/Group%20Project/FilmEMO/crawler.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> for movie_name in movies[26:]:
# ...

# %%
for movie_name in movies:
    crawler = RTTCrawler(movie_name)
    critics = crawler.extract_critics_comments_and_ratings("All critics")
    if critics:
        crawler.write_comments_to_file(critics, "All critics")
    sleep(1)
# Out:
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# No more pages to load, extraction complete
# ...
